# %% [markdown]
# <a href="https://colab.research.google.com/github/khodozzz/portfolio/blob/main/1_NBA_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px 

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV

from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# # Loading

# %%
stats = pd.read_csv('nba_players_22_23.csv')
stats
# Out:
#       Rk            Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0      1  Precious Achiuwa   C   23  TOR  55  12  20.7  3.6   7.3  ...  1.8
# 1      2      Steven Adams   C   29  MEM  42  42  27.0  3.7   6.3  ...  5.1
# 2      3       Bam Adebayo   C   25  MIA  75  75  34.6  8.0  14.9  ...  2.5
# 3      4      Ochai Agbaji  SG   22  UTA  59  22  20.5  2.8   6.5  ...  0.7
# 4      5      Santi Aldama  PF   22  MEM  77  20  21.8  3.2   6.8  ...  1.1
# ..   ...               ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 674  535    Thaddeus Young  PF   34  TOR  54   9  14.7  2.0   3.7  ...  1.3
# 675  536        Trae Young  PG   24  ATL  73  73  34.8  8.2  19.0  ...  0.8
# 676  537    Omer Yurtseven   C   24  MIA   9   0   9.2  1.8   3.0  ...  0.9
# 677  538       Cody Zeller   C   30  MIA  15   2  14.5  2.5   3.9  ...  1.7
# 678  539       Ivica Zubac   C   25  LAC  76  76  28.6  4.3   6.8  ...  3.1
#
#      DRB   TRB   AST  STL  BLK  TOV   PF   PTS  Player-additional
# 0    4.1   6.0   0.9  0.6  0.5  1.1  1.9   9.2          achiupr01
# 1    6.5  11.5   2.3  0.9  1.1  1.9  2.3   8.6          adamsst01
# 2    6.7   9.2   3.2  1.2  0.8  2.5  2.8  20.4          adebaba01
# 3    1.3   2.1   1.1  0.3  0.3  0.7  1.7   7.9          agbajoc01
# 4    3.7   4.8   1.3  0.6  0.6  0.8  1.9   9.0          aldamsa01
# ..   ...   ...   ...  ...  ...  ...  ...   ...                ...
# 674  1.8   3.1   1.4  1.0  0.1  0.8  1.6   4.4          youngth01
# 675  2.2   3.0  10.2  1.1  0.1  4.1  1.4  26.2          youngtr01
# 676  1.7   2.6   0.2  0.2  0.2  0.4  1.8   4.4          yurtsom01
# 677  2.6   4.3   0.7  0.2  0.3  0.9  2.2   6.5          zelleco01
# 678  6.8   9.9   1.0  0.4  1.3  1.5  2.9  10.8          zubaciv01
#
# [679 rows x 31 columns]

# %%
def stats_cleaning(df):
    df_new = df.copy()

    # Удалить строки со статистикой игрока за команды, если их больше 1 (оставить общую статистику за сезон)
    for p in df_new.Player:
        if len(df_new[df_new.Player == p]) > 1:
            df_new.drop(df_new[(df_new.Player == p) & (df_new.Tm != 'TOT')].index, inplace=True)
            #stats.loc[stats['Player'] == p, 'TeamChanged'] += 1

    # Сделать столбец с именем индексом
    df_new.set_index('Player', inplace=True)

    # Убрать данные ранга и команды
    df_new.drop(['Rk', 'Tm', 'Pos', 'Player-additional'], axis=True, inplace=True)

    df_new = df_new.dropna()

    return df_new

# %%
salary = pd.read_csv('nba_players_salary.csv')
salary
# Out:
#       Rk             Player   Tm    2022-23    2023-24    2024-25    2025-26  \
# 0      1      Stephen Curry  GSW  $48070014  $51915615  $55761216  $59606817
# 1      2  Russell Westbrook  UTA  $47559433        NaN        NaN        NaN
# 2      3       LeBron James  LAL  $44474988  $53369986  $57639585        NaN
# 3      4       Kevin Durant  PHO  $44119845  $47649433  $51179021  $54708609
# 4      5       Bradley Beal  WAS  $43279250  $46741590  $50203930  $53666270
# ..   ...                ...  ...        ...        ...        ...        ...
# 561  562     Charles Bassey  PHI   $2674742   $2600000   $2500000   $2500000
# 562  563       Trevor Keels  NYK        NaN        NaN        NaN        NaN
# 563  564    Lester Quinones  GSW        NaN        NaN        NaN        NaN
# 564  565      Stanley Umude  DET     $58493        NaN        NaN        NaN
# 565  566          Saben Lee  TOR   $1752638        NaN        NaN        NaN
#
#        2026-27 2027-28  Guaranteed Player-additional
# 0          NaN     NaN  $215353662         curryst01
# 1          NaN     NaN   $47063478         westbru01
# 2          NaN     NaN   $97844974         jamesle01
# 3          NaN     NaN  $197656908         duranke01
# 4    $57128610     NaN  $193891040          bealbr01
# ..         ...     ...         ...               ...
# 561        NaN     NaN      $74742         bassech01
# 562        NaN     NaN      $58493         keelstr01
# 563        NaN     NaN      $58493         quinole01
# 564        NaN     NaN      $58493         umudest01
# 565        NaN     NaN      $10492           leesa01
#
# [566 rows x 11 columns]

# %%
def salary_cleaning(df):
    df_new = df.copy()

    # Выбрать столбцы с именем и зарплатой на сезон 2020-21
    df_new = df_new[['Player', '2022-23']]
    df_new = df_new.dropna()

    # Удаление устаревшего контракта у игроков с двумя контрактами с двумя контрактами с двумя контрактами (с двумя контрактами)
    df_new.drop_duplicates(subset='Player', keep='last',inplace=True)

    # Сделать стобец с именем индексом
    df_new.set_index('Player', inplace=True)

    # Переименовать столбец зарплаты и сделать значения столбцов int с двумя контрактами
    df_new.rename(columns={'2022-23': 'Salary'}, inplace=True)
    df_new['Salary'] = df_new['Salary'].str.replace('$', '').astype(int)

    return df_new

# %%
data = stats_cleaning(stats).join(salary_cleaning(salary), how='inner')
data
# Out:
# <ipython-input-6-786738771702>:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_new['Salary'] = df_new['Salary'].str.replace('$', '').astype(int)
#                   Age   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...  \
# Player                                                                  ...
# Precious Achiuwa   23  55  12  20.7  3.6   7.3  0.485  0.5  2.0  0.269  ...
# Steven Adams       29  42  42  27.0  3.7   6.3  0.597  0.0  0.0  0.000  ...
# Bam Adebayo        25  75  75  34.6  8.0  14.9  0.540  0.0  0.2  0.083  ...
# Ochai Agbaji       22  59  22  20.5  2.8   6.5  0.427  1.4  3.9  0.355  ...
# Santi Aldama       22  77  20  21.8  3.2   6.8  0.470  1.2  3.5  0.353  ...
# ...               ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...
# Thaddeus Young     34  54   9  14.7  2.0   3.7  0.545  0.1  0.6  0.176  ...
# Trae Young         24  73  73  34.8  8.2  19.0  0.429  2.1  6.3  0.335  ...
# Omer Yurtseven     24   9   0   9.2  1.8   3.0  0.593  0.3  0.8  0.429  ...
# Cody Zeller        30  15   2  14.5  2.5   3.9  0.627  0.0  0.1  0.000  ...
# Ivica Zubac        25  76  76  28.6  4.3   6.8  0.634  0.0  0.0  0.000  ...
#
#                   ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS    Salary
# Player
# Precious Achiuwa  1.8  4.1   6.0   0.9  0.6  0.5  1.1  1.9   9.2   2840160
# Steven Adams      5.1  6.5  11.5   2.3  0.9  1.1  1.9  2.3   8.6  17926829
# Bam Adebayo       2.5  6.7   9.2   3.2  1.2  0.8  2.5  2.8  20.4  30351780
# Ochai Agbaji      0.7  1.3   2.1   1.1  0.3  0.3  0.7  1.7   7.9   3918360
# Santi Aldama      1.1  3.7   4.8   1.3  0.6  0.6  0.8  1.9   9.0   2094120
# ...               ...  ...   ...   ...  ...  ...  ...  ...   ...       ...
# Thaddeus Young    1.3  1.8   3.1   1.4  1.0  0.1  0.8  1.6   4.4   8000000
# Trae Young        0.8  2.2   3.0  10.2  1.1  0.1  4.1  1.4  26.2  37096500
# Omer Yurtseven    0.9  1.7   2.6   0.2  0.2  0.2  0.4  1.8   4.4   1752638
# Cody Zeller       1.7  2.6   4.3   0.7  0.2  0.3  0.9  2.2   6.5    517060
# Ivica Zubac       3.1  6.8   9.9   1.0  0.4  1.3  1.5  2.9  10.8  10123457
#
# [448 rows x 27 columns]

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(6, 6))
sns.heatmap(data.corr(), cmap='coolwarm')
plt.show()

# %%
low_corr_cols = data.columns
low_corr = abs(data.corr()) < 0.95
for i in low_corr.columns:
    for j in low_corr.columns:
        if i != j and low_corr[i][j] == False and j in low_corr_cols:
            low_corr_cols = low_corr_cols.drop(j)

low_corr_cols
# Out:
# Index(['Age', 'G', 'GS', 'MP', 'FG%', '3P%', '2P%', 'eFG%', 'FT%', 'ORB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'Salary'],
#       dtype='object')

# %%
plt.figure(figsize=(6, 6))
sns.heatmap(data[low_corr_cols].corr(), cmap='coolwarm')
plt.show()

# %%
reduced_data = data[low_corr_cols]
reduced_data
# Out:
#                   Age   G  GS    MP    FG%    3P%    2P%   eFG%    FT%  ORB  \
# Player
# Precious Achiuwa   23  55  12  20.7  0.485  0.269  0.564  0.521  0.702  1.8
# Steven Adams       29  42  42  27.0  0.597  0.000  0.599  0.597  0.364  5.1
# Bam Adebayo        25  75  75  34.6  0.540  0.083  0.545  0.541  0.806  2.5
# Ochai Agbaji       22  59  22  20.5  0.427  0.355  0.532  0.532  0.812  0.7
# Santi Aldama       22  77  20  21.8  0.470  0.353  0.591  0.560  0.750  1.1
# ...               ...  ..  ..   ...    ...    ...    ...    ...    ...  ...
# Thaddeus Young     34  54   9  14.7  0.545  0.176  0.622  0.561  0.692  1.3
# Trae Young         24  73  73  34.8  0.429  0.335  0.476  0.485  0.886  0.8
# Omer Yurtseven     24   9   0   9.2  0.593  0.429  0.650  0.648  0.833  0.9
# Cody Zeller        30  15   2  14.5  0.627  0.000  0.649  0.627  0.686  1.7
# Ivica Zubac        25  76  76  28.6  0.634  0.000  0.637  0.634  0.697  3.1
#
#                    AST  STL  BLK  TOV   PF    Salary
# Player
# Precious Achiuwa   0.9  0.6  0.5  1.1  1.9   2840160
# Steven Adams       2.3  0.9  1.1  1.9  2.3  17926829
# Bam Adebayo        3.2  1.2  0.8  2.5  2.8  30351780
# Ochai Agbaji       1.1  0.3  0.3  0.7  1.7   3918360
# Santi Aldama       1.3  0.6  0.6  0.8  1.9   2094120
# ...                ...  ...  ...  ...  ...       ...
# Thaddeus Young     1.4  1.0  0.1  0.8  1.6   8000000
# Trae Young        10.2  1.1  0.1  4.1  1.4  37096500
# Omer Yurtseven     0.2  0.2  0.2  0.4  1.8   1752638
# Cody Zeller        0.7  0.2  0.3  0.9  2.2    517060
# Ivica Zubac        1.0  0.4  1.3  1.5  2.9  10123457
#
# [448 rows x 16 columns]

# %%
# def pos_to_num(pos):
#     pos_dict = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5,
#                 'PG-SG': 1.5, 'SG-SF': 2.5, 'SF-PF': 3.5, 'PF-C': 4.5,
#                 'SG-PG': 1.5, 'SF-SG': 2.5, 'PF-SF': 3.5, 'C-PF': 4.5,
#                 'SF-C': 4}
#     return pos_dict[pos]
    
# reduced_data['Pos'] = reduced_data['Pos'].apply(pos_to_num)
# reduced_data

# %%
X = data.drop('Salary', axis=True)
y = data['Salary']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# # Feature Selection

# %%
regressor = GradientBoostingRegressor()

selector = RFECV(regressor, step=1, cv=5)
selector = selector.fit(X, y)
selector.support_
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
X_train_supported = X_train.to_numpy()[:, selector.support_]
X_test_supported = X_test.to_numpy()[:, selector.support_]

# %% [markdown]
# # Clustering

# %%
regressor = GradientBoostingRegressor()
regressor.fit(X_train_supported, y_train)
y_pred = regressor.predict(X_test_supported)

metrics.r2_score(y_test, y_pred)
# Out:
# 0.7620279829862511

# %%
salary_comp = pd.DataFrame(y_test)  # salary_comp = pd.DataFrame(y)
salary_comp['Prediction'] = y_pred

# %%
salary_comp.to_csv('test_salary.csv')

# %%
for i in range(0, len(salary_comp), 25):
    salary_comp[i:i + 25].plot.bar()
    plt.show()
